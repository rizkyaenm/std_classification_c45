# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %matplotlib inline

# %%
from __setup import *
from __functions import *

# %% [markdown]
# # Summaries

# %% [markdown]
# ## Original

# %% [markdown]
# ### Summary data Original IPA IPK

# %%
# df = pd.read_csv('WekaResultClassifier/final/kelulusan/oversampling mipa/Unpruned_TestingResult.csv')
# display(df)

df1= pd.read_csv('DataResult/original/mipa-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               64.7215                 35.2785  0.3556
# 1               0.02               71.6180                 28.3820  0.4608
# 2               0.03               71.6180                 28.3820  0.4608
# 3               0.04               71.6180                 28.3820  0.4608
# 4               0.05               71.6180                 28.3820  0.4608
# 5               0.06               71.6180                 28.3820  0.4608
# 6               0.07               71.6180                 28.3820  0.4608
# 7               0.08               71.3528                 28.6472  0.4413
# 8               0.09               71.3528                 28.6472  0.4413
# 9               0.10               71.3528                 28.6472  0.4413
# 10              0.11               71.3528                 28.6472  0.4413
# ...

# %% [markdown]
# ### Summary data Original IPA Lulus

# %%
df1= pd.read_csv('DataResult/original/mipa-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               49.7340                 50.2660  0.1546
# 1               0.02               52.3936                 47.6064  0.0000
# 2               0.03               52.3936                 47.6064  0.0000
# 3               0.04               54.5213                 45.4787  0.0681
# 4               0.05               54.5213                 45.4787  0.0681
# 5               0.06               54.5213                 45.4787  0.0681
# 6               0.07               54.5213                 45.4787  0.0681
# 7               0.08               54.5213                 45.4787  0.0681
# 8               0.09               57.9787                 42.0213  0.1824
# 9               0.10               57.9787                 42.0213  0.1824
# 10              0.11               57.9787                 42.0213  0.1824
# ...

# %% [markdown]
# ### Summary data Original Sosial IPK

# %%
df1= pd.read_csv('DataResult/original/sosial-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               65.8228                 34.1772  0.4082
# 1               0.02               69.6203                 30.3797  0.3803
# 2               0.03               69.6203                 30.3797  0.3803
# 3               0.04               70.1627                 29.8373  0.3962
# 4               0.05               70.1627                 29.8373  0.3962
# 5               0.06               70.1627                 29.8373  0.3962
# 6               0.07               70.1627                 29.8373  0.3962
# 7               0.08               70.3436                 29.6564  0.3873
# 8               0.09               70.3436                 29.6564  0.3873
# 9               0.10               70.3436                 29.6564  0.3873
# 10              0.11               70.3436                 29.6564  0.3873
# ...

# %% [markdown]
# ### Summary data Original Sosial Lulus

# %%
df1= pd.read_csv('DataResult/original/sosial-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               51.0830                 48.9170  0.2161
# 1               0.02               57.7617                 42.2383  0.2834
# 2               0.03               57.7617                 42.2383  0.2834
# 3               0.04               57.7617                 42.2383  0.2834
# 4               0.05               57.7617                 42.2383  0.2834
# 5               0.06               57.7617                 42.2383  0.2858
# 6               0.07               57.7617                 42.2383  0.2858
# 7               0.08               57.7617                 42.2383  0.2858
# 8               0.09               57.7617                 42.2383  0.2858
# 9               0.10               58.3032                 41.6968  0.2965
# 10              0.11               58.3032                 41.6968  0.2965
# ...

# %% [markdown]
# ## Oversampling

# %% [markdown]
# ### Summary data Oversampling IPA IPK

# %%
df1= pd.read_csv('DataResult/oversampling/mipa-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               61.5385                 38.4615  0.3583
# 1               0.02               63.6605                 36.3395  0.3967
# 2               0.03               63.9257                 36.0743  0.4008
# 3               0.04               63.9257                 36.0743  0.4008
# 4               0.05               63.9257                 36.0743  0.4008
# 5               0.06               63.6605                 36.3395  0.3980
# 6               0.07               63.3952                 36.6048  0.3933
# 7               0.08               63.3952                 36.6048  0.3933
# 8               0.09               63.3952                 36.6048  0.3933
# 9               0.10               62.3342                 37.6658  0.3822
# 10              0.11               62.3342                 37.6658  0.3848
# ...

# %% [markdown]
# ### Summary data Oversampling IPA Lulus

# %%
df1= pd.read_csv('DataResult/oversampling/mipa-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               39.6277                 60.3723  0.0657
# 1               0.02               43.0851                 56.9149  0.1756
# 2               0.03               42.8191                 57.1809  0.1726
# 3               0.04               43.0851                 56.9149  0.1740
# 4               0.05               41.7553                 58.2447  0.1602
# 5               0.06               41.2234                 58.7766  0.1457
# 6               0.07               40.6915                 59.3085  0.1405
# 7               0.08               41.2234                 58.7766  0.1449
# 8               0.09               41.7553                 58.2447  0.1504
# 9               0.10               42.0213                 57.9787  0.1494
# 10              0.11               42.5532                 57.4468  0.1488
# ...

# %% [markdown]
# ### Summary data Oversampling Sosial IPK

# %%
df1= pd.read_csv('DataResult/oversampling/sosial-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               59.3128                 40.6872  0.3508
# 1               0.02               57.1429                 42.8571  0.3709
# 2               0.03               57.5045                 42.4955  0.3676
# 3               0.04               58.4087                 41.5913  0.3758
# 4               0.05               58.2278                 41.7722  0.3730
# 5               0.06               59.6745                 40.3255  0.3905
# 6               0.07               59.4937                 40.5063  0.3883
# 7               0.08               59.4937                 40.5063  0.3883
# 8               0.09               59.4937                 40.5063  0.3883
# 9               0.10               58.7703                 41.2297  0.3792
# 10              0.11               58.7703                 41.2297  0.3792
# ...

# %% [markdown]
# ### Summary data Oversampling Sosial Lulus

# %%
df1= pd.read_csv('DataResult/oversampling/sosial-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               48.0144                 51.9856  0.2116
# 1               0.02               46.5704                 53.4296  0.2140
# 2               0.03               47.4729                 52.5271  0.2186
# 3               0.04               47.1119                 52.8881  0.2158
# 4               0.05               46.2094                 53.7906  0.2036
# 5               0.06               45.8484                 54.1516  0.2010
# 6               0.07               46.0289                 53.9711  0.2031
# 7               0.08               46.7509                 53.2491  0.2104
# 8               0.09               47.1119                 52.8881  0.2147
# 9               0.10               46.9314                 53.0686  0.2131
# 10              0.11               46.9314                 53.0686  0.2131
# ...

# %% [markdown]
# ## Demografis

# %% [markdown]
# ### Summary data Demografis Ipa -Ipk

# %%
df1= pd.read_csv('DataResult/demografis/mipa-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               48.8064                 51.1936  0.0500
# 1               0.02               61.5385                 38.4615  0.0000
# 2               0.03               61.5385                 38.4615  0.0000
# 3               0.04               61.5385                 38.4615  0.0000
# 4               0.05               61.5385                 38.4615  0.0000
# 5               0.06               61.5385                 38.4615  0.0000
# 6               0.07               61.5385                 38.4615  0.0000
# 7               0.08               61.5385                 38.4615  0.0000
# 8               0.09               61.5385                 38.4615  0.0000
# 9               0.10               61.5385                 38.4615  0.0000
# 10              0.11               61.5385                 38.4615  0.0000
# ...

# %% [markdown]
# ### Summary data Demografis Ipa Lulus

# %%
df1= pd.read_csv('DataResult/demografis/mipa-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               41.4894                 58.5106 -0.0195
# 1               0.02               52.3936                 47.6064  0.0000
# 2               0.03               52.3936                 47.6064  0.0000
# 3               0.04               52.3936                 47.6064  0.0000
# 4               0.05               52.3936                 47.6064  0.0000
# 5               0.06               52.3936                 47.6064  0.0000
# 6               0.07               52.3936                 47.6064  0.0000
# 7               0.08               52.3936                 47.6064  0.0000
# 8               0.09               52.3936                 47.6064  0.0000
# 9               0.10               52.3936                 47.6064  0.0000
# 10              0.11               52.3936                 47.6064  0.0000
# ...

# %% [markdown]
# ### Summary data Demografis Sosial IPK

# %%
df1= pd.read_csv('DataResult/demografis/sosial-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               47.9204                 52.0796  0.0897
# 1               0.02               58.9512                 41.0488  0.0000
# 2               0.03               58.9512                 41.0488  0.0000
# 3               0.04               58.9512                 41.0488  0.0000
# 4               0.05               58.9512                 41.0488  0.0000
# 5               0.06               58.9512                 41.0488  0.0000
# 6               0.07               58.9512                 41.0488  0.0000
# 7               0.08               58.9512                 41.0488  0.0000
# 8               0.09               58.9512                 41.0488  0.0000
# 9               0.10               58.9512                 41.0488  0.0000
# 10              0.11               58.9512                 41.0488  0.0000
# ...

# %% [markdown]
# ### Summary data Demografis Sosial lULUS

# %%
df1= pd.read_csv('DataResult/demografis/sosial-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               47.1119                 52.8881  0.1523
# 1               0.02               57.0397                 42.9603  0.2689
# 2               0.03               57.0397                 42.9603  0.2689
# 3               0.04               57.0397                 42.9603  0.2689
# 4               0.05               57.0397                 42.9603  0.2689
# 5               0.06               57.0397                 42.9603  0.2689
# 6               0.07               57.0397                 42.9603  0.2689
# 7               0.08               57.0397                 42.9603  0.2689
# 8               0.09               57.0397                 42.9603  0.2689
# 9               0.10               57.0397                 42.9603  0.2689
# 10              0.11               57.0397                 42.9603  0.2689
# ...

# %% [markdown]
# ## Random

# %% [markdown]
# ### Summary data Random Mipa - IPK

# %%
df1= pd.read_csv('DataResult/random/mipa-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               65.0794                 34.9206  0.3648
# 1               0.02               65.8730                 34.1270  0.3516
# 2               0.03               65.8730                 34.1270  0.3516
# 3               0.04               65.8730                 34.1270  0.3516
# 4               0.05               65.8730                 34.1270  0.3516
# 5               0.06               65.8730                 34.1270  0.3516
# 6               0.07               65.8730                 34.1270  0.3516
# 7               0.08               65.6085                 34.3915  0.3680
# 8               0.09               65.6085                 34.3915  0.3680
# 9               0.10               65.6085                 34.3915  0.3680
# 10              0.11               65.6085                 34.3915  0.3680
# ...

# %% [markdown]
# ### Summary data Random Mipa - lULUS

# %%
df1= pd.read_csv('DataResult/random/mipa-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               49.7354                 50.2646  0.1897
# 1               0.02               49.2063                 50.7937  0.0000
# 2               0.03               51.8519                 48.1481  0.1434
# 3               0.04               51.8519                 48.1481  0.1434
# 4               0.05               51.8519                 48.1481  0.1434
# 5               0.06               51.8519                 48.1481  0.1434
# 6               0.07               51.8519                 48.1481  0.1434
# 7               0.08               52.9101                 47.0899  0.1499
# 8               0.09               52.9101                 47.0899  0.1499
# 9               0.10               52.9101                 47.0899  0.1499
# 10              0.11               52.9101                 47.0899  0.1499
# ...

# %% [markdown]
# ### Summary data Random Sosial - IPK

# %%
df1= pd.read_csv('DataResult/random/sosial-ipk/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               60.8303                 39.1697  0.3223
# 1               0.02               68.2310                 31.7690  0.3775
# 2               0.03               68.2310                 31.7690  0.3775
# 3               0.04               68.2310                 31.7690  0.3775
# 4               0.05               68.2310                 31.7690  0.3775
# 5               0.06               67.1480                 32.8520  0.3619
# 6               0.07               67.1480                 32.8520  0.3619
# 7               0.08               67.1480                 32.8520  0.3619
# 8               0.09               66.9675                 33.0325  0.3577
# 9               0.10               66.9675                 33.0325  0.3577
# 10              0.11               66.9675                 33.0325  0.3577
# ...

# %% [markdown]
# ### Summary data Random Sosial -Lulus

# %%
df1= pd.read_csv('DataResult/random/sosial-lulus/summary.csv',index_col=0)
display(df1)
# Out:
#     Confidence Value  Correctly Classified  Incorrectly Classified   Kappa  \
# 0               0.00               49.2780                 50.7220  0.1922
# 1               0.02               59.2058                 40.7942  0.3124
# 2               0.03               59.2058                 40.7942  0.3124
# 3               0.04               59.2058                 40.7942  0.3124
# 4               0.05               59.2058                 40.7942  0.3124
# 5               0.06               59.9278                 40.0722  0.3263
# 6               0.07               59.9278                 40.0722  0.3263
# 7               0.08               59.9278                 40.0722  0.3263
# 8               0.09               60.4693                 39.5307  0.3366
# 9               0.10               60.4693                 39.5307  0.3366
# 10              0.11               60.4693                 39.5307  0.3366
# ...
