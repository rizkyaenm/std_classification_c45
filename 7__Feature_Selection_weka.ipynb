# %%
import os
import traceback
import weka.core.jvm as jvm
# import wekaexamples.helper as helper
from weka.core.converters import Loader
from weka.attribute_selection import ASSearch
from weka.attribute_selection import ASEvaluation
from weka.attribute_selection import AttributeSelection

# %%
def FeatureSelection(data):
    """
    Just runs some example code.
    """

    # load a dataset
    print data
    anneal_file = data
    loader = Loader("weka.core.converters.ArffLoader")
    anneal_data = loader.load_file(anneal_file)
    anneal_data.class_is_last()

    # perform attribute selection
#     helper.print_title("Attribute selection")
    search = ASSearch(classname="weka.attributeSelection.BestFirst", options=["-D", "1", "-N", "5"])
    evaluation = ASEvaluation(classname="weka.attributeSelection.CfsSubsetEval", options=["-P", "1", "-E", "1"])
    attsel = AttributeSelection()
    attsel.search(search)
    attsel.evaluator(evaluation)
    attsel.select_attributes(anneal_data)
    print("# attributes: " + str(attsel.number_attributes_selected))
    print("attributes: " + str(attsel.selected_attributes))
    print("result string:\n" + attsel.results_string)

    # perform ranking
#     helper.print_title("Attribute ranking (2-fold CV)")
    search = ASSearch(classname="weka.attributeSelection.Ranker", options=["-N", "-1"])
    evaluation = ASEvaluation("weka.attributeSelection.InfoGainAttributeEval")
    attsel = AttributeSelection()
    attsel.ranking(True)
    attsel.folds(2)
    attsel.crossvalidation(True)
    attsel.seed(42)
    attsel.search(search)
    attsel.evaluator(evaluation)
    attsel.select_attributes(anneal_data)
    print("ranked attributes:\n" + str(attsel.ranked_attributes))
    print("result string:\n" + attsel.results_string)

def main():
    data = ["DataPreprocessing/data_mipa_ipk.arff",
           "DataPreprocessing/data_mipa_lulus.arff",
           "DataPreprocessing/data_sosial_ipk.arff",
           "DataPreprocessing/data_sosial_lulus.arff"]
    for index in range(0,len(data)):
        FeatureSelection(data[index])
        
    

if __name__ == "__main__":
    try:
        jvm.start()
        main()
    except Exception, e:
        print(traceback.format_exc())
    finally:
        jvm.stop()
# Out:
# DEBUG:weka.core.jvm:Adding bundled jars
# DEBUG:weka.core.jvm:Classpath=['c:\\python27\\lib\\site-packages\\javabridge\\jars\\rhino-1.7R4.jar', 'c:\\python27\\lib\\site-packages\\javabridge\\jars\\runnablequeue.jar', 'c:\\python27\\lib\\site-packages\\javabridge\\jars\\cpython.jar', 'c:\\python27\\lib\\site-packages\\weka\\lib\\python-weka-wrapper.jar', 'c:\\python27\\lib\\site-packages\\weka\\lib\\weka.jar']
# DEBUG:weka.core.jvm:MaxHeapSize=default
# DEBUG:weka.core.jvm:Package support disabled
# DEBUG:javabridge.jutil:Creating JVM object
# DEBUG:javabridge.jutil:Signalling caller
# DataPreprocessing/data_mipa_ipk.arff
# # attributes: 3
# attributes: [ 1  8  9 10]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 53
# 	Merit of best subset found:    0.326
#
# Attribute Subset Evaluator (supervised, Class (nominal): 11 IPK_TERAKHIR):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 2,9,10 : 3
#                      JUR
#                      IP_S1
#                      IP_S2
#
# ranked attributes:
# [[9.         0.46399211]
#  [8.         0.38548846]
#  [1.         0.07922636]
#  [7.         0.06330376]
#  [0.         0.01865747]
#  [2.         0.01639892]
#  [6.         0.01625258]
#  [4.         0.01579366]
#  [5.         0.01536955]
#  [3.         0.01418135]]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Attribute ranking.
#
# Attribute Evaluator (supervised, Class (nominal): 11 IPK_TERAKHIR):
# 	Information Gain Ranking Filter
#
# Ranked attributes:
#  0.464   10 IP_S2
#  0.3855   9 IP_S1
#  0.0792   2 JUR
#  0.0633   8 SKS_S2
#  0.0187   1 JK
#  0.0164   3 GAJI_ORTU
#  0.0163   7 SKS_S1
#  0.0158   5 PEK_IBU
#  0.0154   6 PEK_AYAH
#  0.0142   4 PDK_IBU
#
# Selected attributes: 10,9,2,8,1,3,7,5,6,4 : 10
#
#
# === Attribute selection 2 fold cross-validation (stratified), seed: 42 ===
#
# average merit      average rank  attribute
#  0.473 +- 0.02      1   +- 0      10 IP_S2
#  0.39  +- 0.01      2   +- 0       9 IP_S1
#  0.083 +- 0         3   +- 0       2 JUR
#  0.067 +- 0.015     4   +- 0       8 SKS_S2
#  0.036 +- 0.006     5.5 +- 0.5     5 PEK_IBU
#  0.022 +- 0.013     7.5 +- 2.5     1 JK
#  0.02  +- 0.004     8   +- 0       4 PDK_IBU
#  0.027 +- 0.004     8   +- 1       3 GAJI_ORTU
#  0.02  +- 0.008     8   +- 1       7 SKS_S1
#  0.026 +- 0.011     8   +- 2       6 PEK_AYAH
#
# DataPreprocessing/data_mipa_lulus.arff
# # attributes: 6
# attributes: [ 0  1  5  7  8  9 10]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 55
# 	Merit of best subset found:    0.081
#
# Attribute Subset Evaluator (supervised, Class (nominal): 11 STATUS_LULUS):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 1,2,6,8,9,10 : 6
#                      JK
#                      JUR
#                      PEK_AYAH
#                      SKS_S2
#                      IP_S1
#                      IP_S2
#
# ranked attributes:
# [[9.00000000e+00 1.03736559e-01]
#  [8.00000000e+00 7.25330648e-02]
#  [1.00000000e+00 6.16241145e-02]
#  [7.00000000e+00 3.85380921e-02]
#  [0.00000000e+00 3.77385987e-02]
#  [5.00000000e+00 2.09672202e-02]
#  [6.00000000e+00 1.59202867e-02]
#  [2.00000000e+00 1.48839152e-02]
#  [4.00000000e+00 9.64391228e-03]
#  [3.00000000e+00 4.75988957e-03]]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Attribute ranking.
#
# Attribute Evaluator (supervised, Class (nominal): 11 STATUS_LULUS):
# 	Information Gain Ranking Filter
#
# Ranked attributes:
#  0.10374  10 IP_S2
#  0.07253   9 IP_S1
#  0.06162   2 JUR
#  0.03854   8 SKS_S2
#  0.03774   1 JK
#  0.02097   6 PEK_AYAH
#  0.01592   7 SKS_S1
#  0.01488   3 GAJI_ORTU
#  0.00964   5 PEK_IBU
#  0.00476   4 PDK_IBU
#
# Selected attributes: 10,9,2,8,1,6,7,3,5,4 : 10
#
#
# === Attribute selection 2 fold cross-validation (stratified), seed: 42 ===
#
# average merit      average rank  attribute
#  0.108 +- 0.012     1   +- 0      10 IP_S2
#  0.08  +- 0.014     2   +- 0       9 IP_S1
#  0.071 +- 0.009     3   +- 0       2 JUR
#  0.039 +- 0.002     4.5 +- 0.5     1 JK
#  0.044 +- 0.01      5   +- 1       8 SKS_S2
#  0.035 +- 0.002     5.5 +- 0.5     6 PEK_AYAH
#  0.025 +- 0.005     7   +- 0       3 GAJI_ORTU
#  0.023 +- 0.005     8   +- 0       5 PEK_IBU
#  0.021 +- 0.006     9   +- 0       7 SKS_S1
#  0.012 +- 0.003    10   +- 0       4 PDK_IBU
#
# DataPreprocessing/data_sosial_ipk.arff
# # attributes: 3
# attributes: [ 3  8  9 10]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 52
# 	Merit of best subset found:    0.214
#
# Attribute Subset Evaluator (supervised, Class (nominal): 11 IPK_TERAKHIR):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 4,9,10 : 3
#                      PDK_IBU
#                      IP_S1
#                      IP_S2
#
# ranked attributes:
# [[8.         0.28469589]
#  [9.         0.28146221]
#  [7.         0.14711541]
#  [1.         0.12990417]
#  [6.         0.05615565]
#  [0.         0.05553782]
#  [5.         0.01685714]
#  [3.         0.01581475]
#  [4.         0.01299286]
#  [2.         0.00996285]]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Attribute ranking.
#
# Attribute Evaluator (supervised, Class (nominal): 11 IPK_TERAKHIR):
# 	Information Gain Ranking Filter
#
# Ranked attributes:
#  0.2847    9 IP_S1
#  0.28146  10 IP_S2
#  0.14712   8 SKS_S2
#  0.1299    2 JUR
#  0.05616   7 SKS_S1
#  0.05554   1 JK
#  0.01686   6 PEK_AYAH
#  0.01581   4 PDK_IBU
#  0.01299   5 PEK_IBU
#  0.00996   3 GAJI_ORTU
#
# Selected attributes: 9,10,8,2,7,1,6,4,5,3 : 10
#
#
# === Attribute selection 2 fold cross-validation (stratified), seed: 42 ===
#
# average merit      average rank  attribute
#  0.289 +- 0.016     1.5 +- 0.5     9 IP_S1
#  0.285 +- 0.001     1.5 +- 0.5    10 IP_S2
#  0.152 +- 0.017     3.5 +- 0.5     8 SKS_S2
#  0.133 +- 0.012     3.5 +- 0.5     2 JUR
#  0.06  +- 0.002     5.5 +- 0.5     7 SKS_S1
#  0.059 +- 0.001     5.5 +- 0.5     1 JK
#  0.028 +- 0.009     7.5 +- 0.5     6 PEK_AYAH
#  0.019 +- 0.001     8.5 +- 0.5     3 GAJI_ORTU
#  0.021 +- 0.001     8.5 +- 1.5     4 PDK_IBU
#  0.018 +- 0.002     9.5 +- 0.5     5 PEK_IBU
#
# DataPreprocessing/data_sosial_lulus.arff
# # attributes: 5
# attributes: [ 0  1  2  7  9 10]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 56
# 	Merit of best subset found:    0.107
#
# Attribute Subset Evaluator (supervised, Class (nominal): 11 STATUS_LULUS):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 1,2,3,8,10 : 5
#                      JK
#                      JUR
#                      GAJI_ORTU
#                      SKS_S2
#                      IP_S2
#
# ranked attributes:
# [[9.00000000e+00 1.37114173e-01]
#  [1.00000000e+00 8.76150283e-02]
#  [7.00000000e+00 8.73910194e-02]
#  [8.00000000e+00 8.63750910e-02]
#  [0.00000000e+00 5.80101714e-02]
#  [6.00000000e+00 1.82353609e-02]
#  [2.00000000e+00 1.52185803e-02]
#  [3.00000000e+00 8.27707928e-03]
#  [5.00000000e+00 7.53011670e-03]
#  [4.00000000e+00 4.62653228e-03]]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Attribute ranking.
#
# Attribute Evaluator (supervised, Class (nominal): 11 STATUS_LULUS):
# 	Information Gain Ranking Filter
#
# Ranked attributes:
#  0.13711  10 IP_S2
#  0.08762   2 JUR
#  0.08739   8 SKS_S2
#  0.08638   9 IP_S1
#  0.05801   1 JK
#  0.01824   7 SKS_S1
#  0.01522   3 GAJI_ORTU
#  0.00828   4 PDK_IBU
#  0.00753   6 PEK_AYAH
#  0.00463   5 PEK_IBU
#
# Selected attributes: 10,2,8,9,1,7,3,4,6,5 : 10
#
#
# === Attribute selection 2 fold cross-validation (stratified), seed: 42 ===
#
# average merit      average rank  attribute
#  0.139 +- 0.007     1   +- 0      10 IP_S2
#  0.091 +- 0.003     3   +- 0       8 SKS_S2
#  0.089 +- 0.006     3   +- 1       2 JUR
#  0.091 +- 0.016     3   +- 1       9 IP_S1
#  0.058 +- 0.005     5   +- 0       1 JK
#  0.023 +- 0.001     6   +- 0       3 GAJI_ORTU
#  0.022 +- 0.001     7   +- 0       7 SKS_S1
#  0.014 +- 0.002     8.5 +- 0.5     4 PDK_IBU
#  0.017 +- 0.001     8.5 +- 0.5     6 PEK_AYAH
#  0.012 +- 0.002    10   +- 0       5 PEK_IBU
